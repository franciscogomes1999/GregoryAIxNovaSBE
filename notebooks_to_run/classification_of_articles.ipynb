# %% [markdown]
# # **Classification Notebook (NovaSBE X GregoryAI)**

# %% [markdown]
# ![Description of the image](../images/classify_pipeline_diagram.png)

# %% [markdown]
# ## 1. Import libraries

# %%
import os
import sys
import pandas as pd
import numpy as np
from datetime import datetime
import warnings

# Add the parent directory of code_utils to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))

# Suppress warnings
warnings.filterwarnings("ignore")

from code_utils.text_utils import *  # Import everything from text_utils.py
from code_utils.model_utils.LSTM_algorithm_utils import *  
from code_utils.model_utils.BERT_algorithm_utils import *  
from code_utils.model_utils.LGBM_algorithm_utils import *  
from code_utils.model_utils.classify_model_choose import *
from code_utils.download_utils import *
# Out:
# WARNING:tensorflow:From c:\Users\marti\venv\pbl\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## 2. Download articles

# %%
# load the previous data
old_articles_path = '..\\data\\articles_08-06-2024_14h13m04s.csv'
url = 'https://gregory-ms.com/developers/articles.zip'
download_and_extract_zip(url, old_articles_path, 'max')
# Out:
# DataFrame saved to data\2024-06-09\train_articles.csv
# DataFrame saved to data\2024-06-09\inference_articles.csv
# (                                                        title  \
#  article_id
#  1            COVID-19, HHV6 and MOG antibody: A perfect storm
#  2           Is Migraine Associated to Brain Anatomical Alt...
#  3           Patient Satisfaction With the Quality of Couns...
#  4           Rare Case of Spinal Neurosarcoidosis with Conc...
#  5           Evaluation of Urinary Tract Infection followin...
#  ...                                                       ...
#  25079       In Vitro and Ex Vivo Methodologies for T-Cell ...
#  25080       Correction to "Comparative adherence trajector...
#  25081       Comparing face-to-face and videoconference ass...
#  25232       The development of a core outcome set for stud...
#  25233       TDP-43-regulated cryptic RNAs accumulate in Al...
#
#                                                        summary  \
#  article_id
#  1           J Neuroimmunol. 2021 Feb 12;353:577521. doi: 1...
#  2           Brain Topogr. 2021 Feb 19. doi: 10.1007/s10548...
#  3           J Neurosci Nurs. 2021 Feb 17. doi: 10.1097/JNN...
#  4           Case Rep Neurol Med. 2021 Jan 28;2021:5952724....
#  5           Can J Infect Dis Med Microbiol. 2021 Jan 31;20...
#  ...                                                       ...
#  25079       Methods Mol Biol. 2023;2700:199-219. doi: 10.1...
#  25080       Pharmacotherapy. 2023 Aug 21. doi: 10.1002/pha...
#  25081       Mult Scler. 2023 Aug 21:13524585231192469. doi...
#  25232       Abstract Background Heterogeneity in reported ...
#  25233       Abstract Background Inclusions of TAR DNA-bind...
#
#                                                           link published_date  \
#  article_id
#  1           https://pubmed.ncbi.nlm.nih.gov/33607505/?fc=2...     2021-04-14
#  2           https://pubmed.ncbi.nlm.nih.gov/33606142/?fc=2...     2021-01-05
#  3           https://pubmed.ncbi.nlm.nih.gov/33605649/?fc=2...     2021-03-31
#  4           https://pubmed.ncbi.nlm.nih.gov/33604089/?fc=2...     2021-01-28
#  5           https://pubmed.ncbi.nlm.nih.gov/33603936/?fc=2...     2021-01-31
#  ...                                                       ...            ...
#  25079       https://pubmed.ncbi.nlm.nih.gov/37603183/?fc=2...     2023-08-21
#  25080       https://pubmed.ncbi.nlm.nih.gov/37602980/?fc=2...     2023-08-21
#  25081       https://pubmed.ncbi.nlm.nih.gov/37602442/?fc=2...     2023-08-21
#  25232       https://bmcmedicine.biomedcentral.com/articles...     2023-08-20
#  25233       https://molecularneurodegeneration.biomedcentr...     2023-08-20
#
#             discovery_date  source                                  publisher  \
#  article_id
#  1              2021-02-23     8.0                                Elsevier BV
#  2              2021-02-23     8.0    Springer Science and Business Media LLC
#  3              2021-02-23     8.0  Ovid Technologies (Wolters Kluwer Health)
#  4              2021-02-23     8.0                            Hindawi Limited
#  5              2021-02-23     8.0                            Hindawi Limited
#  ...                   ...     ...                                        ...
#  25079          2023-08-21     8.0                                Springer US
#  25080          2023-08-21     8.0                                      Wiley
#  25081          2023-08-21     8.0                          SAGE Publications
#  25232          2023-08-21     2.0    Springer Science and Business Media LLC
#  25233          2023-08-21     2.0    Springer Science and Business Media LLC
#
#                                                container_title  \
#  article_id
#  1                                  Journal of Neuroimmunology
#  2                                            Brain Topography
#  3                             Journal of Neuroscience Nursing
#  4                       Case Reports in Neurological Medicine
#  5           Canadian Journal of Infectious Diseases and Me...
#  ...                                                       ...
#  25079                            Methods in Molecular Biology
#  25080       Pharmacotherapy: The Journal of Human Pharmaco...
#  25081                              Multiple Sclerosis Journal
#  25232                                            BMC Medicine
#  25233                             Molecular Neurodegeneration
#
#                                                        authors relevant  \
#  article_id
#  1           Ali Fadhil, Ankita Prasad, Anthony Zampino, Fa...    False
#  2           Anne Caclin, Aurélie Bidet-Caulet, David Meuni...    False
#  3           Daniela Händler-Schuster, Diana Zanolari, Gabr...    False
#  4           Achraf Makki, Maria Khoueiry, Nesreen Jaafar, ...      NaN
#  5           Aliyeh Bazi, Monireh Ghazaeian, Narjes Hendoie...    False
#  ...                                                       ...      ...
#  25079       Alessandra Pistilli, Anna Maria Stabile, Camil...      NaN
#  25080                                                     NaN      NaN
#  25081       Daniela Malangone, Elisabetta Signoriello, Gab...      NaN
#  25232       Adeniyi Francis Fagbamigbe, Amaya Azcoaga-Lore...      NaN
#  25233       Bailey Rawlinson, Bradley F. Boeve, David S. K...    False
#
#                                         doi      access  \
#  article_id
#  1           10.1016/j.jneuroim.2021.577521        open
#  2               10.1007/s10548-021-00824-6        open
#  3             10.1097/JNN.0000000000000578  restricted
#  4                     10.1155/2021/5952724        open
#  5                     10.1155/2021/6616763        open
#  ...                                    ...         ...
#  25079         10.1007/978-1-0716-3366-3_12  restricted
#  25080                    10.1002/phar.2846  restricted
#  25081            10.1177/13524585231192469  restricted
#  25232           10.1186/s12916-023-03013-3  restricted
#  25233           10.1186/s13024-023-00646-z  restricted
#
#                                                      takeaways categories
#  article_id
#  1            First case of HHV6 reactivation in central ne...        NaN
#  2            Growing number of studies investigate brain a...        NaN
#  3            The challenges in dealing with multiple scler...        NaN
#  4            Spinal neurosarcoidosis is a rare disease tha...        NaN
#  5            Double-blind randomized clinical trial was co...        NaN
#  ...                                                       ...        ...
#  25079       This chapter describes ex vivo isolation of hu...        NaN
#  25080                                                     NaN        NaN
#  25081       The COVID-19 pandemic has highlighted the need...        NaN
#  25232       Heterogeneity in reported outcomes can limit t...        NaN
#  25233       30-70% of Alzheimer's disease (AD) cases prese...        NaN
#
#  [8005 rows x 14 columns],
#                                                          title  \
#  article_id
#  1277953     Toll-like receptor 10 is down-regulated in ser...
#  229393      The consequences of delayed diagnosis and trea...
#  229394      Mini review of photoacoustic clinical imaging:...
#  229395      Novel Pyrazolopyridine Inhibitors of Monoacylg...
#  229396      Study to Compare the Efficacy and Cost-Effecti...
#  ...                                                       ...
#  32745       A short washout period from fingolimod to anti...
#  32746       Protective effect of exogenous peroxiredoxin 6...
#  32747       Intervention fidelity and adaptation in a mult...
#  32748       Early use of high efficacy therapies in pediat...
#  32749       Real world study of ocrelizumab in multiple sc...
#
#                                                        summary  \
#  article_id
#  1277953     J Neurovirol. 2023 Mar 18. doi: 10.1007/s13365...
#  229393      Diagnosis (Berl). 2024 Jan 18. doi: 10.1515/dx...
#  229394      J Biomed Opt. 2024 Jan;29(Suppl 1):S11522. doi...
#  229395      ACS Med Chem Lett. 2024 Jan 2;15(1):19-20. doi...
#  229396      Ann Indian Acad Neurol. 2023 Nov-Dec;26(6):895...
#  ...                                                       ...
#  32745       Rev Neurol (Paris). 2023 Aug 24:S0035-3787(23)...
#  32746       Arch Biochem Biophys. 2023 Aug 24:109729. doi:...
#  32747       Contemp Clin Trials. 2023 Aug 24:107320. doi: ...
#  32748       Mult Scler Relat Disord. 2023 Aug 13;79:104942...
#  32749       Mult Scler Relat Disord. 2023 Aug 18;79:104941...
#
#                                                           link published_date  \
#  article_id
#  1277953     https://pubmed.ncbi.nlm.nih.gov/36934201/?fc=2...     2023-03-19
#  229393      https://pubmed.ncbi.nlm.nih.gov/38230519/?fc=2...     2024-01-17
#  229394      https://pubmed.ncbi.nlm.nih.gov/38230369/?fc=2...     2024-01-17
#  229395      https://pubmed.ncbi.nlm.nih.gov/38229740/?fc=2...     2024-01-17
#  229396      https://pubmed.ncbi.nlm.nih.gov/38229623/?fc=2...     2024-01-17
#  ...                                                       ...            ...
#  32745       https://pubmed.ncbi.nlm.nih.gov/37633735/?fc=2...     2023-08-26
#  32746       https://pubmed.ncbi.nlm.nih.gov/37633587/?fc=2...     2023-08-26
#  32747       https://pubmed.ncbi.nlm.nih.gov/37633458/?fc=2...     2023-08-26
#  32748       https://pubmed.ncbi.nlm.nih.gov/37633034/?fc=2...     2023-08-26
#  32749       https://pubmed.ncbi.nlm.nih.gov/37633033/?fc=2...     2023-08-26
#
#             discovery_date  source                                 publisher  \
#  article_id
#  1277953        2023-03-19     8.0                  Journal of NeuroVirology
#  229393         2024-01-17     8.0                    Walter de Gruyter GmbH
#  229394         2024-01-17     8.0              Journal of Biomedical Optics
#  229395         2024-01-17     8.0           ACS Medicinal Chemistry Letters
#  229396         2024-01-17     8.0     Annals of Indian Academy of Neurology
#  ...                   ...     ...                                       ...
#  32745          2023-08-27     8.0                        Revue Neurologique
#  32746          2023-08-27     8.0   Archives of Biochemistry and Biophysics
#  32747          2023-08-27     8.0              Contemporary Clinical Trials
#  32748          2023-08-27     8.0  Multiple Sclerosis and Related Disorders
#  32749          2023-08-27     8.0  Multiple Sclerosis and Related Disorders
#
#                                       container_title  \
#  article_id
#  1277953                     Journal of NeuroVirology
#  229393                                     Diagnosis
#  229394                  Journal of Biomedical Optics
#  229395               ACS Medicinal Chemistry Letters
#  229396         Annals of Indian Academy of Neurology
#  ...                                              ...
#  32745                             Revue Neurologique
#  32746        Archives of Biochemistry and Biophysics
#  32747                   Contemporary Clinical Trials
#  32748       Multiple Sclerosis and Related Disorders
#  32749       Multiple Sclerosis and Related Disorders
#
#                                                        authors relevant  \
#  article_id
#  1277953        Ali H. Ad’hiah, Hula Y. Fadhil, Noor S. Atiyah      NaN
#  229393      Andrés Gómez-de-León, Daniela Sánchez-Bonilla,...      NaN
#  229394      Fei Ji, Huazhen Liu, Meng Yang, Ming Wang, Yux...      NaN
#  229395                                           Gerard Rosse     True
#  229396      Mukul Sehrawat, Santhosh K. Madhusudhan, Shubh...      NaN
#  ...                                                       ...      ...
#  32745       A. Garmendia, C. Louapre, C. Papeix, E. Mailla...      NaN
#  32746       A.A. Kuzekova, E.G. Novoselova, E.K. Mubaraksh...     True
#  32747       Amanda L. Penko, Ashlie Ithurburn, Brendon Tru...      NaN
#  32748       Andreas Fickl, Augustin Moreau, Christel Dente...      NaN
#  32749       Jasem Al-Hashel, Malak AlMojel, Raed Alroughan...      NaN
#
#                                         doi      access  \
#  article_id
#  1277953         10.1007/s13365-023-01124-4  restricted
#  229393                10.1515/dx-2023-0157  restricted
#  229394          10.1117/1.JBO.29.S1.S11522        open
#  229395      10.1021/acsmedchemlett.3c00548        open
#  229396            10.4103/aian.aian_467_23        open
#  ...                                    ...         ...
#  32745         10.1016/j.neurol.2023.03.028  restricted
#  32746            10.1016/j.abb.2023.109729  restricted
#  32747            10.1016/j.cct.2023.107320  restricted
#  32748          10.1016/j.msard.2023.104942  restricted
#  32749          10.1016/j.msard.2023.104941  restricted
#
#                                                      takeaways  \
#  article_id
#  1277953      Toll-like receptor 10 (TLR10) and Epstein-Bar...
#  229393      The time elapsed between the onset of symptoms...
#  229394      Photoacoustic (PA) imaging is an imaging modal...
#  229395                                                    NaN
#  229396      Natalizumab, rituximab, and glatiramer acetate...
#  ...                                                       ...
#  32745       The frequency of switches between Disease Modi...
#  32746       Both thymulin and Prx6 significantly improved ...
#  32747       The current paper summarizes fidelity of study...
#  32748       The study compared the effectiveness of early ...
#  32749       Ocrelizumab is a humanized anti-CD20 antibody ...
#
#                      categories
#  article_id
#  1277953     Epstein-Barr Virus
#  229393       aHSCT, Stem Cells
#  229394                     NaN
#  229395                     NaN
#  229396                     NaN
#  ...                        ...
#  32745               Fingolimod
#  32746                      NaN
#  32747                      NaN
#  32748                      NaN
#  32749              Ocrelizumab
#
#  [17263 rows x 14 columns])

# %% [markdown]
# ## 2. Load articles, clean and pre-process articles

# %%
dataset_path = os.path.join('../data/2024-06-09', # choose the day folder intended to use 
                            'inference_articles.csv')

# additional step to ensure consistency in the index column formating as article_id
articles_df = pd.read_csv(dataset_path)

# if the first column is not article_id, remove that first column

if articles_df.columns[0] != 'article_id':
    articles_df = articles_df.drop(columns=articles_df.columns[0])

articles_clean_df = load_and_format_dataset(dataset_path, text_cleaning_pd_series)

articles_clean_df.head()
# Out:
#                                                text_processed   relevant
# article_id
# 1277953     tolllike receptor 10 downregulated serum patie...  unlabeled
# 229393      consequences delayed diagnosis treatment perso...  unlabeled
# 229394      mini review photoacoustic clinical imaging non...  unlabeled
# 229395      novel pyrazolopyridine inhibitors monoacylglyc...          1
# 229396      study compare efficacy costeffectiveness vario...  unlabeled

# %%
articles_clean_df.relevant.value_counts()
# Out:
# relevant
# unlabeled    14792
# 0             1114
# 1              734
# Name: count, dtype: int64

# %% [markdown]
# **Filter to keep Unlabelled Data**

# %%
unlabeled_articles = articles_clean_df[articles_clean_df['relevant'] == 'unlabeled']
unlabeled_texts = unlabeled_articles['text_processed']
article_ids = unlabeled_articles.index

# %% [markdown]
# ## 4. Classify Articles (predict Labels for Unlabeled Articles)

# %%
model_path = '../models/lgbm_classifier.joblib'
vectorizer_path = '../models/tfidf_vectorizer.joblib'

# List of available models
models_available = ['LSTM_Classifier', 'BERT_Classifier', 'LGBM_TFIDF_Classifier']

# Choose the model
model_name = models_available[2]  # This can be set dynamically by the user

# Predict labels for the unlabeled articles
predicted_labels = predict_with_model(model_name, model_path, vectorizer_path, unlabeled_texts)
# Out:
# Model loaded: vectorizer from ../models/tfidf_vectorizer.joblib, classifier from ../models/lgbm_classifier.joblib
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[6], line 11
#       8 model_name = models_available[2]  # This can be set dynamically by the user
#      10 # Predict labels for the unlabeled articles
# ---> 11 predicted_labels = predict_with_model(model_name, model_path, vectorizer_path, unlabeled_texts)
#
# File c:\Users\marti\OneDrive - Nova SBE\Nova\Master's in Business Analytics\Disciplinas\PBL\GregoryAIxNovaSBE\code_utils\model_utils\classify_model_choose.py:20, in predict_with_model(model_name, model_path, vectorizer_path, data)
#      18     model_instance = LGBM_TFIDF_Classifier()
#      19     model_instance.load_model(vectorizer_path, model_path)
# ---> 20     predictions = model_instance.predict(data)
#      21 else:
#      22     raise ValueError("Unsupported model name: {}".format(model_name))
#
# File c:\Users\marti\OneDrive - Nova SBE\Nova\Master's in Business Analytics\Disciplinas\PBL\GregoryAIxNovaSBE\code_utils\model_utils\LGBM_algorithm_utils.py:86, in LGBM_TFIDF_Classifier.predict(self, X)
#      83 if not self.fitted:
#      84     raise Exception("Model not trained. Call `train` method first.")
# ---> 86 X_transformed = self.vectorizer.transform(X)
#      87 print("Data Vectorized")
#      88 return self.classifier.predict(X_transformed)
#
# File c:\Users\marti\venv\pbl\Lib\site-packages\sklearn\feature_extraction\text.py:2163, in TfidfVectorizer.transform(self, raw_documents)
#    2160 check_is_fitted(self, msg="The TF-IDF vectorizer is not fitted")
#    2162 X = super().transform(raw_documents)
# -> 2163 return self._tfidf.transform(X, copy=False)
#
# File c:\Users\marti\venv\pbl\Lib\site-packages\sklearn\feature_extraction\text.py:1724, in TfidfTransformer.transform(self, X, copy)
#    1718     X.data += 1
#    1720 if self.use_idf:
#    1721     # idf_ being a property, the automatic attributes detection
#    1722     # does not work as usual and we need to specify the attribute
#    1723     # name:
# -> 1724     check_is_fitted(self, attributes=["idf_"], msg="idf vector is not fitted")
#    1726     X = X @ self._idf_diag
#    1728 if self.norm is not None:
#
# File c:\Users\marti\venv\pbl\Lib\site-packages\sklearn\utils\validation.py:1622, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1619     raise TypeError("%s is not an estimator instance." % (estimator))
#    1621 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1622     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: idf vector is not fitted

# %% [markdown]
# ## 5. Store the results

# %%
# Create a new DataFrame with article IDs and predicted labels
results_df = pd.DataFrame({
    'article_id': article_ids,
    f'{model_name}_pred': predicted_labels
})

# Reset the index to ensure article_id is a column and not an index
results_df.reset_index(drop=True, inplace=True)

# %%
# Join the results with the original DataFrame

df = pd.read_csv('../articles_downloads/articles_08-06-2024_14h13m04s.csv')

new_articles_df = df.merge(results_df, how='left', left_on='article_id', right_on='article_id')

new_articles_df.head()
# Out:
#    Unnamed: 0  article_id                                              title  \
# 0           0           1   COVID-19, HHV6 and MOG antibody: A perfect storm
# 1           1           2  Is Migraine Associated to Brain Anatomical Alt...
# 2           2           3  Patient Satisfaction With the Quality of Couns...
# 3           3           4  Rare Case of Spinal Neurosarcoidosis with Conc...
# 4           4           5  Evaluation of Urinary Tract Infection followin...
#
#                                              summary  \
# 0  J Neuroimmunol. 2021 Feb 12;353:577521. doi: 1...
# 1  Brain Topogr. 2021 Feb 19. doi: 10.1007/s10548...
# 2  J Neurosci Nurs. 2021 Feb 17. doi: 10.1097/JNN...
# 3  Case Rep Neurol Med. 2021 Jan 28;2021:5952724....
# 4  Can J Infect Dis Med Microbiol. 2021 Jan 31;20...
#
#                                                 link published_date  \
# 0  https://pubmed.ncbi.nlm.nih.gov/33607505/?fc=2...     2021-04-14
# 1  https://pubmed.ncbi.nlm.nih.gov/33606142/?fc=2...     2021-01-05
# 2  https://pubmed.ncbi.nlm.nih.gov/33605649/?fc=2...     2021-03-31
# 3  https://pubmed.ncbi.nlm.nih.gov/33604089/?fc=2...     2021-01-28
# 4  https://pubmed.ncbi.nlm.nih.gov/33603936/?fc=2...     2021-01-31
#
#   discovery_date  source                                  publisher  \
# 0     2021-02-23     8.0                                Elsevier BV
# 1     2021-02-23     8.0    Springer Science and Business Media LLC
# 2     2021-02-23     8.0  Ovid Technologies (Wolters Kluwer Health)
# 3     2021-02-23     8.0                            Hindawi Limited
# 4     2021-02-23     8.0                            Hindawi Limited
#
#                                      container_title  \
# 0                         Journal of Neuroimmunology
# 1                                   Brain Topography
# 2                    Journal of Neuroscience Nursing
# 3              Case Reports in Neurological Medicine
# 4  Canadian Journal of Infectious Diseases and Me...
#
#                                              authors relevant  \
# 0  Ali Fadhil, Ankita Prasad, Anthony Zampino, Fa...    False
# 1  Anne Caclin, Aurélie Bidet-Caulet, David Meuni...    False
# 2  Daniela Händler-Schuster, Diana Zanolari, Gabr...    False
# 3  Achraf Makki, Maria Khoueiry, Nesreen Jaafar, ...      NaN
# 4  Aliyeh Bazi, Monireh Ghazaeian, Narjes Hendoie...    False
#
#                               doi      access  \
# 0  10.1016/j.jneuroim.2021.577521        open
# 1      10.1007/s10548-021-00824-6        open
# 2    10.1097/JNN.0000000000000578  restricted
# 3            10.1155/2021/5952724        open
# 4            10.1155/2021/6616763        open
#
#                                            takeaways categories  \
# 0   First case of HHV6 reactivation in central ne...        NaN
# 1   Growing number of studies investigate brain a...        NaN
# 2   The challenges in dealing with multiple scler...        NaN
# 3   Spinal neurosarcoidosis is a rare disease tha...        NaN
# 4   Double-blind randomized clinical trial was co...        NaN
#
#    LGBM_TFIDF_Classifier_pred
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         0.0
# 4                         NaN

# %%
# Export the new DataFrame to a CSV file into the folder articles_classification,
# with name formating as follows: articles_predictions_{model_name}_{current_date}_{current_time}.csv

def get_current_date_time():
    now = datetime.now()
    current_date = now.strftime('%Y-%m-%d')
    current_time = now.strftime('%H-%M-%S')
    return current_date, current_time

current_date = get_current_date_time()[0]
current_time = get_current_date_time()[1]

output_filename = f'articles_predictions_{model_name}_{current_date}_{current_time}.csv'

output_path = os.path.join('../articles_classification', output_filename)

new_articles_df.to_csv(output_path, index=False)
